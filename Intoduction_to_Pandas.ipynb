# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabh5240/Python-Libraries/blob/main/Intoduction_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import numpy as np

# %%
#To import the data csv file which we have uploaded by path or by name
data_dia = pd.read_csv("/content/diabetes.csv")

# %%
boston_dataset = pd.read_csv("HousingData.csv")

# %%
type(boston_dataset)  #its directly as dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Directly here i got as data frame.
# To import data from library
# - from sklearn import load_boston
# -boston_dataset = load_boston()
#
# Then to convert this data into data frame use
# -  boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)

# %%
boston_dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90    NaN   36.2

# %%
boston_dataset.shape
# Out:
# (506, 14)

# %%
data_dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data_dia.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading a excel file to pandas data frame
# - file = pd.read_excel("file path")

# %%
#Export a data frame to csv file

boston_dataset.to_csv("boston.csv")

# %% [markdown]
# Exporting pandas dataframe to a excel file
# - boston_dataset.to_excel("Filename")

# %%
#create a data set with random values
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.125535  0.937480  0.572112  0.678503  0.582869  0.247554  0.123057
# 1  0.025168  0.834086  0.148394  0.100562  0.763329  0.032783  0.559497
# 2  0.341183  0.435264  0.419369  0.183518  0.555384  0.449717  0.905863
# 3  0.047754  0.041002  0.587645  0.659756  0.846743  0.369464  0.066342
# 4  0.932933  0.547763  0.412595  0.118567  0.418055  0.087145  0.442974
#
#           7         8         9
# 0  0.577126  0.219236  0.127920
# 1  0.893222  0.331974  0.186158
# 2  0.590570  0.456441  0.765170
# 3  0.100939  0.137014  0.815189
# 4  0.855435  0.655562  0.399739

# %%
random_df.shape
# Out:
# (20, 10)

# %%
#Inspecting a dataframe
boston_dataset.shape
# Out:
# (506, 14)

# %%
#dataset.head() for first five
boston_dataset.tail() #For last five
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  PRICE
# 501  391.99    NaN   22.4
# 502  396.90   9.08   20.6
# 503  396.90   5.64   23.9
# 504  393.45   6.48   22.0
# 505  396.90   7.88   11.9

# %%
#to get info about dataset
boston_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
#To find the numbe rof missing values
boston_dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# PRICE       0
# dtype: int64

# %%
data_dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#To count values based on label

data_dia.value_counts("Outcome")
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
#group the values based on mean
data_dia.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
#count or number of values column wise
boston_dataset.count()
# Out:
# CRIM       486
# ZN         486
# INDUS      486
# CHAS       486
# NOX        506
# RM         506
# AGE        486
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      486
# PRICE      506
# dtype: int64

# %%
#To get mean column wise
boston_dataset.mean()
# Out:
# CRIM         3.611874
# ZN          11.211934
# INDUS       11.083992
# CHAS         0.069959
# NOX          0.554695
# RM           6.284634
# AGE         68.518519
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.715432
# PRICE       22.532806
# dtype: float64

# %%
#To get standard deviation column wise
boston_dataset.std()
# Out:
# CRIM         8.720192
# ZN          23.388876
# INDUS        6.835896
# CHAS         0.255340
# NOX          0.115878
# RM           0.702617
# AGE         27.999513
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.155871
# PRICE        9.197104
# dtype: float64

# %%
# To get min value column wise
boston_dataset.min()
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# PRICE        5.00000
# dtype: float64

# %%
#To get max value column wise
boston_dataset.max()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# PRICE       50.0000
# dtype: float64

# %%
#All the statistical data in dataframe
boston_dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Manipulating data frame

# %% [markdown]
# To add a column to DataFrame
# - boston_dataset["Price"] = boston_dataset.target()

# %%
boston_dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90    NaN   36.2

# %%
#To drop a row
boston_dataset.drop(index = 0 ,axis=0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 1    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  PRICE
# ...

# %%
#To drop a column
boston_dataset.drop(columns = 'ZN',axis =1)
# Out:
#         CRIM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  PRICE
# 0    396.90   4.98   24.0
# 1    396.90   9.14   21.6
# ...

# %%
#To locate a row and get corresponding details
boston_dataset.iloc[2]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# PRICE       34.70000
# Name: 2, dtype: float64

# %%
#To locate a column
boston_dataset.iloc[:,0]  #Fisrt column
boston_dataset.iloc[:,-1]  #Last column
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
#Correlation - 1.Positive and negative
boston_dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# ...

# %% [markdown]
# #Importing data through kaggle API
# -API - Application Programming Interface

# %%
#installing Kaggle library
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Uploading your kaggle.json file

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# Importing the eartquake dataset

# %%
#Api ti fetch the dataset from kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.9/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.9/dist-packages/kaggle/api/kaggle_api_extended.py", line 164, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
#extracting the compressed dataset
from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-d0505e9eb26a> in <module>
#       3 dataset = '/content/LANL-Earthquake-Prediction.zip'
#       4
# ----> 5 with ZipFile(dataset,'r') as zip:
#       6   zip.extractall()
#       7   print('The dataset is extracted')
#
# /usr/lib/python3.9/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1246             while True:
#    1247                 try:
# -> 1248                     self.fp = io.open(file, filemode)
#    1249                 except OSError:
#    1250                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/LANL-Earthquake-Prediction.zip'

# %%
sub = pd.read_csv('sample_submission.csv')

# %%
sub.head()

# %%
import seaborn as sns
